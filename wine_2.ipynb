# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df_red = pd.read_csv("winequality-red.csv", sep = ";")
df_white = pd.read_csv("winequality-white.csv", sep = ";")

# %%
df_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df_red_original = df_red.copy()
df_white_orginal = df_white.copy()

# %%
df_white['quality_label'] = df_white['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')
df_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df_red['quality_label'] = df_red['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')
df_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_red.hist(bins=15, color="crimson", edgecolor='black', linewidth=1.0, xlabelsize=8, ylabelsize=8, grid=False)

plt.tight_layout(rect=(0, 0, 1.2, 1.2))

rt = plt.suptitle('Red Wine Univariate Plots', x=0.65, y=1.25, fontsize=15)

# %%
df_white.hist(bins=15, color="#17becf", edgecolor='black', linewidth=1.0, xlabelsize=10, ylabelsize=10, grid=False)

plt.tight_layout(rect=(0, 0, 1.2, 1.2))

rt = plt.suptitle('Red Wine Univariate Plots', x=0.65, y=1.25, fontsize=15)

# %%
# make column "dry", "sweet"

# %%
sns.histplot(df_white["residual sugar"] )
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='Count'>

# %%
# residual sugar content in wine with histogram

figure, axs = plt.subplots(1, 2, sharey= "row", figsize =(10,7))

sugar_white = df_white["residual sugar"]
sugar_red = df_red["residual sugar"]  
# For Sine Function

axs[0].set_title("residual sugar white")
axs[1].set_title("residual sugar red")

axs[0].hist(sugar_white, fill = False, edgecolor = "black")
axs[1].hist(sugar_red, color= "red")

plt.ylim(0, 3500)
plt.suptitle("Residual sugar content in wine")

plt.xticks(np.arange(0, 15,2.5))
plt.ylabel("Frequency")
plt.show()

# %%
# same graph with seaborn and subplot number)
plt.figure(figsize=(12, 8))
plt.subplot(121, title = "residual sugar white")
sns.histplot(df_white["residual sugar"], fill = False, edgecolor = "black")
plt.ylabel("Frequency")
plt.subplot(122, title = "residual sugar red")
sns.histplot(df_red["residual sugar"], color = "crimson")
plt.ylabel("Frequency")
#plt.xticks(np.arange(0, 15,2.5))
plt.ylim(0, 1000)
#plt.subplots_adjust(wspace = 0.5)
plt.suptitle("Residual sugar content in wine")
#plt.subplots_adjust(wspace = 0)
plt.show()

plt.show()

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': '#EAEAF2',
#  'axes.edgecolor': 'white',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': 'white',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.round: 'round'>,
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
#plt.figure(figsize=(16,16))
sns.set_style("white")

sns.jointplot(data = df_red, x="quality", y="sulphates", color = "crimson",  marginal_ticks=True,  height=8, ratio=4)
plt.suptitle("Red wine Sulphates - Quality")
plt.subplots_adjust(top= 0.9)
plt.show()

# %%
sns.jointplot(data = df_red, x="quality", y="sulphates", kind = "reg")
plt.show()

# %%
sns.jointplot(data = df_red, x="quality", y="sulphates", kind = "hist")
plt.show()

# %%
sns.jointplot(data = df_white, x="quality", y="sulphates", color = "#17becf",  marginal_ticks=True,  height=8, ratio=4)
plt.suptitle("White wine Sulphates - Quality")
plt.subplots_adjust(top= 0.9)
plt.show()

# %%
sns.jointplot(data = df_white, x="quality", y="sulphates", kind = "hist")
plt.show()

# %%
# red wine scatterplot with 3 variables (alcohol, sulphates and quality_label)

plt.figure(figsize =(10,7))
sns.scatterplot(data=df_red, x="alcohol", y="sulphates", hue="quality_label", palette = "OrRd")
plt.show()

# %%
# white wine scatterplot with 3 variables (alcohol, sulphates and quality_label)

plt.figure(figsize =(10,7))
sns.scatterplot(data=df_white, x="alcohol", y="sulphates", hue="quality_label", hue_order = ["low", "medium", "high"], palette = "cool")
plt.title("alcohol and sulphates in white wine")
plt.show()

# %%
# red wine scatterplot with 3 variables, total sulfur dioxide, free sulfur dioxide and quality label 

plt.figure(figsize =(10,7))
sns.scatterplot(data=df_red, x="total sulfur dioxide", y="free sulfur dioxide", hue="quality_label", 
               hue_order = ["low", "medium", "high"], palette = "OrRd")
plt.show()

# %%
# white wine scatterplot with 3 variables, total sulfur dioxide, free sulfur dioxide and quality label 

plt.figure(figsize =(10,7))
sns.scatterplot(data=df_white, x="total sulfur dioxide", y="free sulfur dioxide", hue="quality_label", 
               hue_order = ["low", "medium", "high"], palette = "cool")
plt.show()

# %%
plt.figure(figsize =(10,7))
sns.regplot(data=df_white, x="total sulfur dioxide", y="free sulfur dioxide", )
plt.show()

# %%
sns.jointplot(data = df_white, x="total sulfur dioxide", y="free sulfur dioxide", color = "#17becf",  marginal_ticks=True,  height=8, ratio=4)
plt.suptitle("White wine total sulfur dioxide and free sulfur dioxide")
plt.subplots_adjust(top= 0.9)
plt.show()

# %%
sns.jointplot(data = df_red, x="total sulfur dioxide", y="free sulfur dioxide", color = "crimson", 
               marginal_ticks=True,  height=8, ratio=4)
plt.suptitle("red wine total sulfur dioxide and free sulfur dioxide")
plt.subplots_adjust(top= 0.9)
plt.show()

# %%
# red wine scatterplot with 3 variables, fixed acidity, citric acid and quality label
plt.figure(figsize =(10,7))
sns.scatterplot(data=df_red, x="fixed acidity", y="citric acid",hue="quality_label", 
               hue_order = ["low", "medium", "high"], palette = "OrRd")
plt.show()

# %%
# red wine scatterplot with 3 variables, fixed acidity, density and quality label

plt.figure(figsize =(10,7))
sns.scatterplot(data=df_red, x="fixed acidity", y="density",hue="quality_label", 
               hue_order = ["low", "medium", "high"], palette = "OrRd")
plt.title("fixed acidity and density in red wine") 
plt.show()

# %%
plt.figure(figsize =(10,7))
sns.scatterplot(data = df_white, x="fixed acidity", y="density",hue="quality_label", 
               hue_order = ["low", "medium", "high"], palette = "cool")
plt.title("fixed acidity and density in white wine") 


plt.show()

# %%
# red wine scatterplot with 3 variables, pH, fixed acidity and quality label
plt.figure(figsize =(10,7))
sns.scatterplot(data=df_red, x="pH", y="fixed acidity",hue="quality_label", 
               hue_order = ["low", "medium", "high"], palette = "OrRd")
plt.title("pH and fixed acidity in red wine") 
plt.show()

# %%
plt.figure(figsize =(10,7))
sns.scatterplot(data=df_white, x="pH", y="fixed acidity",hue="quality_label", 
               hue_order = ["low", "medium", "high"], palette = "cool")
plt.title("pH and fixed acidity in white wine") 
plt.ylim(4, 16.5)
plt.show()

# %%
plt.figure(figsize =(10,7))
sns.scatterplot(data=df_white, x="residual sugar", y="density",hue="quality_label", 
               hue_order = ["low", "medium", "high"], palette = "cool")
plt.xlim(0,35)
plt.title("white wine: correlation between residual sugar, density and quality label")
plt.show()

# %%
plt.figure(figsize =(10,7))
sns.scatterplot(data=df_white, x="alcohol", y="density",hue="quality_label", 
               hue_order = ["low", "medium", "high"], palette = "cool")
plt.xlim(0,35)
plt.title("white wine: correlation between alcohol, density and quality label")
plt.xlim(7, 15)
plt.show()

# %%
fig, ax = plt.subplots(1,2)

hue_order =  ['low', 'medium', 'high']
ax[0,0].set_title("alcohol content and quality label in white wine")
ax[0,0].sns.displot(data=df_white, x="alcohol", hue="quality_label", hue_order = hue_order, kind="kde", fill=True)
ax[0,1].set_title("alcohol content and quality label in red wine")
ax[0,1].sns.displot(data=df_red, x="alcohol", hue="quality_label", hue_order = hue_order, kind="kde", fill=True)
#plt.title("")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [36], line 4
#       1 fig, ax = plt.subplots(1,2)
#       3 hue_order =  ['low', 'medium', 'high']
# ----> 4 ax[0,0].set_title("alcohol content and quality label in white wine")
#       5 ax[0,0].sns.displot(data=df_white, x="alcohol", hue="quality_label", hue_order = hue_order, kind="kde", fill=True)
#       6 ax[0,1].set_title("alcohol content and quality label in red wine")
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
ax1 = sns.displot(data=df_white, x="alcohol", hue="quality_label", hue_order = hue_order, kind="kde", fill=True)
#ax1.set_title("white wine alcohol content with displot")

ax2 = sns.displot(data=df_red, x="alcohol", hue="quality_label", hue_order = hue_order, kind="kde", fill=True)
#ax2.set_title("red wine alcohol content with displot")

plt.show()

# %%
sns.displot(data=df_white, x="alcohol", hue="quality_label", hue_order = hue_order, kind="kde", fill=True)
plt.title("white wine alcohol content with displot")
# Out:
# Text(0.5, 1.0, 'white wine alcohol content with displot')

# %%
sns.displot(data=df_red, x="alcohol", hue="quality_label", hue_order = hue_order, kind="kde", fill=True)
plt.title("red wine alcohol content with displot")
# Out:
# Text(0.5, 1.0, 'red wine alcohol content with displot')

# %%
sns.displot(data=df_white, x="pH", hue="quality_label", kind="kde", fill=True)

# %%
sns.displot(data=df_white, x="residual sugar", hue="quality_label", kind="kde", fill=True)

# %%
plt.figure(figsize =(10,7))
sns.regplot(data=df_white, x="pH", y="fixed acidity", )
plt.show()

# %%
df_white['alcohol_label'] = df_white['alcohol'].apply(lambda value: 'low'
if value <= 11.5 else 'medium'
if value <= 14.5 else 'high')
df_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df_red['alcohol_label'] = df_red['alcohol'].apply(lambda value: 'low'
if value <= 11.5 else 'medium'
if value <= 14.5 else 'high')
df_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
plt.figure(figsize= (10,7)) 
plt.subplot(121, title = "white wine alcohol label and density ")
sns.boxplot(data = df_white, x = 'alcohol_label', y = "density", order = ["low", "medium", "high"])

plt.subplot(122, title = "Red wine alcohol label and density")
sns.boxplot(data = df_red, x = 'alcohol_label', y = "density")

plt.suptitle("alcohol label and its density")
# Out:
# Text(0.5, 0.98, 'alcohol label and its density')

# %%
plt.figure(figsize =(10,7))
sns.scatterplot(data=df_white, x="alcohol", y="density")
plt.xlim(0,35)
plt.title("white wine: correlation between alcohol, density and quality label")
plt.xlim(7, 15)
plt.show()
# Out:
# C:\Users\satom\AppData\Local\Temp\ipykernel_28960\3065802568.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df_white, x="alcohol", y="density", palette = "cool")

# %%
plt.figure(figsize =(10,7))
sns.scatterplot(data=df_red, x="alcohol", y="density")
plt.xlim(0,35)
plt.title("red wine: correlation between alcohol and density")
plt.xlim(7, 15)
plt.show()

# %%
from scipy import stats
import scipy.stats
from scipy.stats import norm


F, p = stats.f_oneway(df_red[df_red['quality_label'] == 'low']['alcohol'],
df_red[df_red['quality_label'] == 'medium']['alcohol'],
df_red[df_red['quality_label'] == 'high']['alcohol'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\np-value:', p, "\nCritical f Value:", scipy.stats.f.ppf(q=1-0.05, dfn=2, dfd=4898))

#from Linh
#The higher the F-value in an ANOVA, the higher the variation between sample means relative to the variation within the samples.
#The higher the F-value, the lower the corresponding p-value.
#If the p-value is below a certain threshold (e.g. α = .05), we can reject the null hypothesis of the ANOVA and 
#conclude that there is a statistically significant difference between group means.

# The F value should always be used along with the p value in deciding whether your results are significant enough to reject the null hypothesis. 
# If you get a large f value (one that is bigger than the F critical value found in a table), it means something is significant, while a small p value means all your results are significant. 
# The F statistic just compares the joint effect of all the variables together. 
# To put it simply, reject the null hypothesis only if your alpha level is larger than your p value.

#H0 rejected, Fcrit > F, p<alpha
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 205.23448800361507
# p-value: 4.776936653588672e-80
# Critical f Value: 2.9975652813719136

# %%
F, p = stats.f_oneway(df_red[df_red['quality_label'] == 'low']['alcohol'],
df_red[df_red['quality_label'] == 'medium']['alcohol'],
df_red[df_red['quality_label'] == 'high']['alcohol'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\np-value:', p, "\nCritical f Value:", scipy.stats.f.ppf(q=0.05, dfn=2, dfd = 1599))
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 205.23448800361507
# p-value: 4.776936653588672e-80
# Critical f Value: 0.05129493982741953

# %%
F, p = stats.f_oneway(df_white[df_white['quality_label'] == 'low']['alcohol'],
df_white[df_white['quality_label'] == 'medium']['alcohol'],
df_white[df_white['quality_label'] == 'high']['alcohol'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\np-value:', p, "\nCritical f Value:", scipy.stats.f.ppf(q=1-0.05, dfn=2, dfd=4898))
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 478.1628922043277
# p-value: 2.0647901873531918e-190
# Critical f Value: 2.9975652813719136

# %%
F, p = stats.f_oneway(df_red[df_red['quality_label'] == 'low']['density'],
df_red[df_red['quality_label'] == 'medium']['density'],
df_red[df_red['quality_label'] == 'high']['density'])
print('ANOVA test for mean density levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p, "\nCritical f Value:", scipy.stats.f.ppf(q=0.05, dfn=2, dfd = 1599))
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 25.018992085108984 	p-value: 2.0009732581386505e-11

# %%
F, p = stats.f_oneway(df_white[df_white['quality_label'] == 'low']['density'],
df_white[df_white['quality_label'] == 'medium']['density'],
df_white[df_white['quality_label'] == 'high']['density'])
print('ANOVA test for mean density levels across wine samples with different quality ratings')
print('F Statistic:', F, '\np-value:', p, "\nCritical f Value:", scipy.stats.f.ppf(q=1-0.05, dfn=2, dfd=4898))
# Out:
# ANOVA test for mean density levels across wine samples with different quality ratings
# F Statistic: 209.69457693191376
# p-value: 4.1941323440944663e-88
# Critical f Value: 2.9975652813719136

# %%
F, p = stats.f_oneway(df_red[df_red['quality_label'] == 'low']['residual sugar'],
df_red[df_red['quality_label'] == 'medium']['residual sugar'],
df_red[df_red['quality_label'] == 'high']['residual sugar'])
print('ANOVA test for mean residual sugar across wine samples with different quality ratings')
print('F Statistic:', F, '\np-value:', p, "\nCritical f Value:", scipy.stats.f.ppf(q=1-0.05, dfn=2, dfd = 1599))
# Out:
# ANOVA test for mean residual sugar across wine samples with different quality ratings
# F Statistic: 0.011800296751587022
# p-value: 0.9882691399198739
# Critical f Value: 3.0013518054014248

# %%
F, p = stats.f_oneway(df_white[df_white['quality_label'] == 'low']['residual sugar'],
df_white[df_white['quality_label'] == 'medium']['residual sugar'],
df_white[df_white['quality_label'] == 'high']['residual sugar'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\np-value:', p, "\nCritical f Value:", scipy.stats.f.ppf(q=1-0.05, dfn=2, dfd = 4898))
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 21.934773835107606
# p-value: 3.2830889157949124e-10
# Critical f Value: 2.9975652813719136

# %%
F, p = stats.f_oneway(df_red[df_red['quality_label'] == 'low']['pH'],
df_red[df_red['quality_label'] == 'medium']['pH'],
df_red[df_red['quality_label'] == 'high']['pH'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\np-value:', p, "\nCritical f Value:", scipy.stats.f.ppf(q=1-0.05, dfn=2, dfd = 1599))
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 0.7354879827479522
# p-value: 0.4794338960102369
# Critical f Value: 3.0013518054014248

# %%
F, p = stats.f_oneway(df_white[df_white['quality_label'] == 'low']['pH'],
df_white[df_white['quality_label'] == 'medium']['pH'],
df_white[df_white['quality_label'] == 'high']['pH'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\np-value:', p, "\nCritical f Value:", scipy.stats.f.ppf(q=1-0.05, dfn=2, dfd = 4898))
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 19.690945958199926
# p-value: 3.0377212959215113e-09
# Critical f Value: 2.9975652813719136

# %%
F, p = stats.f_oneway(df_red[df_red['quality_label'] == 'low']['total sulfur dioxide'],
df_red[df_red['quality_label'] == 'medium']['total sulfur dioxide'],
df_red[df_red['quality_label'] == 'high']['total sulfur dioxide'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\np-value:', p, "\nCritical f Value:", scipy.stats.f.ppf(q=1-0.05, dfn=2, dfd = 1599))
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 45.71048039843774
# p-value: 4.965226898791742e-20
# Critical f Value: 3.0013518054014248

# %%
F, p = stats.f_oneway(df_white[df_white['quality_label'] == 'low']['total sulfur dioxide'],
df_white[df_white['quality_label'] == 'medium']['total sulfur dioxide'],
df_white[df_white['quality_label'] == 'high']['total sulfur dioxide'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\np-value:', p, "\nCritical f Value:", scipy.stats.f.ppf(q=1-0.05, dfn=2, dfd = 4898))
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 76.66028143448855
# p-value: 1.650541621040454e-33
# Critical f Value: 2.9975652813719136

# %%
F, p = stats.f_oneway(df_red[df_red['quality_label'] == 'low']['volatile acidity'],
df_red[df_red['quality_label'] == 'medium']['volatile acidity'],
df_red[df_red['quality_label'] == 'high']['volatile acidity'])
print('ANOVA test for mean volatile acidity across wine samples with different quality ratings')
print('F Statistic:', F, '\np-value:', p, "\nCritical f Value:", scipy.stats.f.ppf(q=1-0.05, dfn=2, dfd = 4898))
# Out:
# ANOVA test for mean volatile acidity across wine samples with different quality ratings
# F Statistic: 92.87437900766831
# p-value: 6.994633687008598e-39
# Critical f Value: 2.9975652813719136

# %%
F, p = stats.f_oneway(df_red[df_red['alcohol_label'] == 'low']['density'],
df_red[df_red['alcohol_label'] == 'medium']['density'],
df_red[df_red['alcohol_label'] == 'high']['density'])
#print('ANOVA test for mean density across wine samples with different quality ratings')
print('F Statistic:', F, '\np-value:', p, "\nCritical f Value:", scipy.stats.f.ppf(q=1-0.05, dfn=2, dfd = 1599))
# Out:
# ANOVA test for mean density across wine samples with different quality ratings
# F Statistic: 164.4498595220424
# p-value: 1.1549754745850244e-65
# Critical f Value: 3.0013518054014248

# %%
F, p = stats.f_oneway(df_white[df_white['alcohol_label'] == 'low']['density'],
df_white[df_white['alcohol_label'] == 'medium']['density'],
df_white[df_white['alcohol_label'] == 'high']['density'])
#print('ANOVA test for mean density across wine samples with different quality ratings')
print('F Statistic:', F, '\np-value:', p, "\nCritical f Value:", scipy.stats.f.ppf(q=1-0.05, dfn=2, dfd = 4898))
# Out:
# F Statistic: nan
# p-value: nan
# Critical f Value: 2.9975652813719136
# c:\Users\satom\anaconda3\lib\site-packages\scipy\stats\_stats_py.py:3872: DegenerateDataWarning: at least one input has length 0
#   warnings.warn(stats.DegenerateDataWarning('at least one input '

# %% [markdown]
# Skewness of each variables in white wine dataset

# %%
print(f"skewness of fixed acidity:",df_white['fixed acidity'].astype(float).skew())
print(f"skewness of volatile acidity:",df_white['volatile acidity'].astype(float).skew())
print(f"skewness of citric acid:",df_white['citric acid'].astype(float).skew())
print(f"skewness of residual sugar:",df_white['residual sugar'].astype(float).skew())
print(f"skewness of chlorides:",df_white['chlorides'].astype(float).skew())
print(f"skewness of free sulfur dioxide:",df_white['free sulfur dioxide'].astype(float).skew())

print(f"skewness of total sulfur dioxide:",df_white['total sulfur dioxide'].astype(float).skew())
print(f"skewness of density:",df_white['density'].astype(float).skew())
print(f"skewness of pH:",df_white['pH'].astype(float).skew())
print(f"skewness of  sulphates:",df_white['sulphates'].astype(float).skew())
print(f"skewness of alcohol:",df_white['alcohol'].astype(float).skew())
print(f"skewness of quality:",df_white['quality'].astype(float).skew())
# Out:
# skewness of fixed acidity: 0.6477514746297539
# skewness of volatile acidity: 1.5769795029952025
# skewness of citric acid: 1.2819203981671066
# skewness of residual sugar: 1.0770937564240868
# skewness of chlorides: 5.023330682759711
# skewness of free sulfur dioxide: 1.4067449205303078
# skewness of total sulfur dioxide: 0.3907098416536745
# skewness of density: 0.9777730048689898
# skewness of pH: 0.4577825459180807
# skewness of  sulphates: 0.9771936833065663
# skewness of alcohol: 0.4873419932161276
# skewness of quality: 0.15579639772222578

# %% [markdown]
# Kurtosis of each variables in white wine dataset

# %%
print(f"Kurtosis of fixed acidity:",df_white['fixed acidity'].astype(float).kurt())
print(f"Kurtosis of volatile acidity:",df_white['volatile acidity'].astype(float).kurt())
print(f"Kurtosis of citric acid:",df_white['citric acid'].astype(float).kurt())
print(f"Kurtosis of residual sugar:",df_white['residual sugar'].astype(float).kurt())
print(f"Kurtosis of chlorides:",df_white['chlorides'].astype(float).kurt())
print(f"Kurtosis of free sulfur dioxide:",df_white['free sulfur dioxide'].astype(float).kurt())
print(f"Kurtosis of total sulfur dioxide:",df_white['total sulfur dioxide'].astype(float).kurt())
print(f"Kurtosis of density:",df_white['density'].astype(float).kurt())
print(f"Kurtosis of pH:",df_white['pH'].astype(float).kurt())
print(f"Kurtosis of  sulphates:",df_white['sulphates'].astype(float).kurt())
print(f"Kurtosis of alcohol:",df_white['alcohol'].astype(float).kurt())
print(f"Kurtosis of quality:",df_white['quality'].astype(float).kurt())
# Out:
# Kurtosis of fixed acidity: 2.1721784645585807
# Kurtosis of volatile acidity: 5.091625816866611
# Kurtosis of citric acid: 6.174900656983394
# Kurtosis of residual sugar: 3.4698201025634265
# Kurtosis of chlorides: 37.56459970667953
# Kurtosis of free sulfur dioxide: 11.466342426607905
# Kurtosis of total sulfur dioxide: 0.5718532333534614
# Kurtosis of density: 9.793806910765252
# Kurtosis of pH: 0.5307749515326159
# Kurtosis of  sulphates: 1.5909296303516225
# Kurtosis of alcohol: -0.6984253277895518
# Kurtosis of quality: 0.21652582721530989

# %% [markdown]
# Skewness of each variables in red wine dataset

# %%
print(f"skewness of fixed acidity:",df_red['fixed acidity'].astype(float).skew())
print(f"skewness of volatile acidity:",df_red['volatile acidity'].astype(float).skew())
print(f"skewness of citric acid:",df_red['citric acid'].astype(float).skew())
print(f"skewness of residual sugar:",df_red['residual sugar'].astype(float).skew())
print(f"skewness of chlorides:",df_red['chlorides'].astype(float).skew())
print(f"skewness of free sulfur dioxide:",df_red['free sulfur dioxide'].astype(float).skew())

print(f"skewness of total sulfur dioxide:",df_red['total sulfur dioxide'].astype(float).skew())
print(f"skewness of density:",df_red['density'].astype(float).skew())
print(f"skewness of pH:",df_red['pH'].astype(float).skew())
print(f"skewness of  sulphates:",df_red['sulphates'].astype(float).skew())
print(f"skewness of alcohol:",df_red['alcohol'].astype(float).skew())
print(f"skewness of quality:",df_red['quality'].astype(float).skew())
# Out:
# skewness of fixed acidity: 0.9827514413284587
# skewness of volatile acidity: 0.6715925723840199
# skewness of citric acid: 0.3183372952546368
# skewness of residual sugar: 4.54065542590319
# skewness of chlorides: 5.680346571971724
# skewness of free sulfur dioxide: 1.250567293314441
# skewness of total sulfur dioxide: 1.515531257594554
# skewness of density: 0.07128766294927483
# skewness of pH: 0.19368349811284427
# skewness of  sulphates: 2.4286723536602945
# skewness of alcohol: 0.8608288068888538
# skewness of quality: 0.21780157547366327

# %%
print(f"Kurtosis of fixed acidity:",df_white['fixed acidity'].astype(float).kurt())
print(f"Kurtosis of volatile acidity:",df_white['volatile acidity'].astype(float).kurt())
print(f"Kurtosis of citric acid:",df_white['citric acid'].astype(float).kurt())
print(f"Kurtosis of residual sugar:",df_white['residual sugar'].astype(float).kurt())
print(f"Kurtosis of chlorides:",df_white['chlorides'].astype(float).kurt())
print(f"Kurtosis of free sulfur dioxide:",df_white['free sulfur dioxide'].astype(float).kurt())
print(f"Kurtosis of total sulfur dioxide:",df_white['total sulfur dioxide'].astype(float).kurt())
print(f"Kurtosis of density:",df_white['density'].astype(float).kurt())
print(f"Kurtosis of pH:",df_white['pH'].astype(float).kurt())
print(f"Kurtosis of  sulphates:",df_white['sulphates'].astype(float).kurt())
print(f"Kurtosis of alcohol:",df_white['alcohol'].astype(float).kurt())
print(f"Kurtosis of quality:",df_white['quality'].astype(float).kurt())
# Out:
# Kurtosis of fixed acidity: 2.1721784645585807
# Kurtosis of volatile acidity: 5.091625816866611
# Kurtosis of citric acid: 6.174900656983394
# Kurtosis of residual sugar: 3.4698201025634265
# Kurtosis of chlorides: 37.56459970667953
# Kurtosis of free sulfur dioxide: 11.466342426607905
# Kurtosis of total sulfur dioxide: 0.5718532333534614
# Kurtosis of density: 9.793806910765252
# Kurtosis of pH: 0.5307749515326159
# Kurtosis of  sulphates: 1.5909296303516225
# Kurtosis of alcohol: -0.6984253277895518
# Kurtosis of quality: 0.21652582721530989

# %% [markdown]
# filter all the white wine that have more than 11.5 and then analyse them

# %%
df_white_highal = df_white["alcohol"] >= 11.5
df_white_highal
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4893    False
# 4894    False
# 4895    False
# 4896     True
# 4897     True
# Name: alcohol, Length: 4898, dtype: bool

# %%
type(df_white_highal), df_white_highal.shape
# Out:
# (pandas.core.series.Series, (4898,))
