# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("winequality-red.csv", sep = ";")
df
# Out:
#      fixed acidity volatile acidity  citric acid residual sugar  chlorides  \
# 0          07. Apr              0.7         0.00        01. Sep      0.076
# 1          07. Aug             0.88         0.00        02. Jun      0.098
# 2          07. Aug             0.76         0.04        02. Mrz      0.092
# 3          11. Feb             0.28         0.56        01. Sep      0.075
# 4          07. Apr              0.7         0.00        01. Sep      0.076
# ...            ...              ...          ...            ...        ...
# 1594       06. Feb              0.6         0.08              2      0.090
# 1595       05. Sep             0.55         0.10        02. Feb      0.062
# 1596       06. Mrz             0.51         0.13        02. Mrz      0.076
# 1597       05. Sep            0.645         0.12              2      0.075
# 1598             6             0.31         0.47        03. Jun      0.067
#
# ...

# %%
df.head(10)
# Out:
#   fixed acidity volatile acidity  citric acid residual sugar  chlorides  \
# 0       07. Apr              0.7         0.00        01. Sep      0.076
# 1       07. Aug             0.88         0.00        02. Jun      0.098
# 2       07. Aug             0.76         0.04        02. Mrz      0.092
# 3       11. Feb             0.28         0.56        01. Sep      0.075
# 4       07. Apr              0.7         0.00        01. Sep      0.076
# 5       07. Apr             0.66         0.00        01. Aug      0.075
# 6       07. Sep              0.6         0.06        01. Jun      0.069
# 7       07. Mrz             0.65         0.00        01. Feb      0.065
# 8       07. Aug             0.58         0.02              2      0.073
# 9       07. Mai              0.5         0.36        06. Jan      0.071
#
#   free sulfur dioxide  total sulfur dioxide  density       pH sulphates  \
# 0                  11                  34.0   0.9978   Mrz 51      0.56
# ...

# %%
df.tail(10)
# Out:
#      fixed acidity volatile acidity  citric acid residual sugar  chlorides  \
# 1589       06. Jun            0.725         0.20        07. Aug      0.073
# 1590       06. Mrz             0.55         0.15        01. Aug      0.077
# 1591       05. Apr             0.74         0.09        01. Jul      0.089
# 1592       06. Mrz             0.51         0.13        02. Mrz      0.076
# 1593       06. Aug             0.62         0.08        01. Sep      0.068
# 1594       06. Feb              0.6         0.08              2      0.090
# 1595       05. Sep             0.55         0.10        02. Feb      0.062
# 1596       06. Mrz             0.51         0.13        02. Mrz      0.076
# 1597       05. Sep            0.645         0.12              2      0.075
# 1598             6             0.31         0.47        03. Jun      0.067
#
#      free sulfur dioxide  total sulfur dioxide  density      pH sulphates  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   object
#  1   volatile acidity      1599 non-null   object
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   object
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   object
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   object
#  9   sulphates             1599 non-null   object
#  10  alcohol               1599 non-null   object
#  11  quality               1599 non-null   int64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 150.0+ KB

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.describe()
# Out:
#        citric acid    chlorides  total sulfur dioxide      density  \
# count  1599.000000  1599.000000           1599.000000  1599.000000
# mean      0.270976     0.087467             46.467792     2.208702
# std       0.194801     0.047065             32.895324     9.664060
# min       0.000000     0.012000              6.000000     0.990070
# 25%       0.090000     0.070000             22.000000     0.995600
# 50%       0.260000     0.079000             38.000000     0.996750
# 75%       0.420000     0.090000             62.000000     0.997835
# max       1.000000     0.611000            289.000000   100.369000
#
#            quality
# count  1599.000000
# mean      5.636023
# std       0.807569
# min       3.000000
# 25%       5.000000
# 50%       6.000000
# 75%       6.000000
# max       8.000000

# %%
df['quality_label'] = df['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')
df
# Out:
#      fixed acidity volatile acidity  citric acid residual sugar  chlorides  \
# 0          07. Apr              0.7         0.00        01. Sep      0.076
# 1          07. Aug             0.88         0.00        02. Jun      0.098
# 2          07. Aug             0.76         0.04        02. Mrz      0.092
# 3          11. Feb             0.28         0.56        01. Sep      0.075
# 4          07. Apr              0.7         0.00        01. Sep      0.076
# ...            ...              ...          ...            ...        ...
# 1594       06. Feb              0.6         0.08              2      0.090
# 1595       05. Sep             0.55         0.10        02. Feb      0.062
# 1596       06. Mrz             0.51         0.13        02. Mrz      0.076
# 1597       05. Sep            0.645         0.12              2      0.075
# 1598             6             0.31         0.47        03. Jun      0.067
#
# ...
