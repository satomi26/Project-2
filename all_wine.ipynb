# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df_red = pd.read_csv("winequality-red.csv", sep = ";")
df_white = pd.read_csv("winequality-white.csv", sep = ";")

# %%
df_red.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df_red.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1589            6.6             0.725         0.20             7.8      0.073
# 1590            6.3             0.550         0.15             1.8      0.077
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df_white.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df_white.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4888            6.8             0.220         0.36            1.20      0.052
# 4889            4.9             0.235         0.27           11.75      0.030
# 4890            6.1             0.340         0.29            2.20      0.036
# 4891            5.7             0.210         0.32            0.90      0.038
# 4892            6.5             0.230         0.38            1.30      0.032
# 4893            6.2             0.210         0.29            1.60      0.039
# 4894            6.6             0.320         0.36            8.00      0.047
# 4895            6.5             0.240         0.19            1.20      0.041
# 4896            5.5             0.290         0.30            1.10      0.022
# 4897            6.0             0.210         0.38            0.80      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df_white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
df_red_original = df_red.copy()
df_white_orginal = df_white.copy()

# %%
df_white["quality"].value_counts(ascending=False)
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %%
df_red["quality"].value_counts(ascending=False)
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
#df_white['citric acid'] = df_white['citric acid'].astype(float)

# %%
# df_white['fixed acidity'] = df_white['fixed acidity'].astype(float)

# %%
# df_white['citric acid'] = df_white['citric acid'].astype(float)

# %%
df_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df_white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
df_red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df_red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df_white['quality_label'] = df_white['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')
df_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df_white["quality_label"].value_counts()
# Out:
# medium    3078
# low       1640
# high       180
# Name: quality_label, dtype: int64

# %%
df_red['quality_label'] = df_red['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')
df_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
#  12  quality_label         1599 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 162.5+ KB

# %%
pd.concat([df_red.describe(), df_white.describe()], axis="columns", keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats                                               \
#         fixed acidity volatile acidity  citric acid residual sugar
# count     1599.000000      1599.000000  1599.000000    1599.000000
# mean         8.319637         0.527821     0.270976       2.538806
# std          1.741096         0.179060     0.194801       1.409928
# min          4.600000         0.120000     0.000000       0.900000
# 25%          7.100000         0.390000     0.090000       1.900000
# 50%          7.900000         0.520000     0.260000       2.200000
# 75%          9.200000         0.640000     0.420000       2.600000
# max         15.900000         1.580000     1.000000      15.500000
#
#                                                                           \
#          chlorides free sulfur dioxide total sulfur dioxide      density
# count  1599.000000         1599.000000          1599.000000  1599.000000
# mean      0.087467           15.874922            46.467792     0.996747
# ...

# %%
df_white.describe().round(2)
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count        4898.00           4898.00      4898.00         4898.00
# mean            6.85              0.28         0.33            6.39
# std             0.84              0.10         0.12            5.07
# min             3.80              0.08         0.00            0.60
# 25%             6.30              0.21         0.27            1.70
# 50%             6.80              0.26         0.32            5.20
# 75%             7.30              0.32         0.39            9.90
# max            14.20              1.10         1.66           65.80
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density       pH  \
# count    4898.00              4898.00               4898.00  4898.00  4898.00
# mean        0.05                35.31                138.36     0.99     3.19
# std         0.02                17.01                 42.50     0.00     0.15
# ...

# %%
df_red.describe().round(2)
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count        1599.00           1599.00      1599.00         1599.00
# mean            8.32              0.53         0.27            2.54
# std             1.74              0.18         0.19            1.41
# min             4.60              0.12         0.00            0.90
# 25%             7.10              0.39         0.09            1.90
# 50%             7.90              0.52         0.26            2.20
# 75%             9.20              0.64         0.42            2.60
# max            15.90              1.58         1.00           15.50
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density       pH  \
# count    1599.00              1599.00               1599.00  1599.00  1599.00
# mean        0.09                15.87                 46.47     1.00     3.31
# std         0.05                10.46                 32.90     0.00     0.15
# ...

# %%
# Mean value of sulfates and volatile acidity seem to be higher in red wine as compared to white wine.
# density seem to be almost same in white and red wine. 
# Mean value of residual sugar in white wine seems to be much highher than it in red wine. 2.5 times more than red wine.
# all value (mean, std, min and max) in density seem to be almost same in white and red wine.
# almost all value (mean, std, min ) in quality seem to be almost same in white and red wine. (except max quality of white wine is 9, and max quality of red wine is 8)
# mean value of total sulfur dioxide in white wine seems three times more than in red wine. 
# mean value of free sulfur disxide in white wine seems more than doublee than in red wine.
# all values in alcohol in red and white wine is very similar
#

# %%
df_white[:-1].round(2)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7       0.04
# 1               6.3              0.30         0.34             1.6       0.05
# 2               8.1              0.28         0.40             6.9       0.05
# 3               7.2              0.23         0.32             8.5       0.06
# 4               7.2              0.23         0.32             8.5       0.06
# ...             ...               ...          ...             ...        ...
# 4892            6.5              0.23         0.38             1.3       0.03
# 4893            6.2              0.21         0.29             1.6       0.04
# 4894            6.6              0.32         0.36             8.0       0.05
# 4895            6.5              0.24         0.19             1.2       0.04
# 4896            5.5              0.29         0.30             1.1       0.02
#
# ...

# %%
df_red[:-1].round(2)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9       0.08
# 1               7.8              0.88         0.00             2.6       0.10
# 2               7.8              0.76         0.04             2.3       0.09
# 3              11.2              0.28         0.56             1.9       0.08
# 4               7.4              0.70         0.00             1.9       0.08
# ...             ...               ...          ...             ...        ...
# 1593            6.8              0.62         0.08             1.9       0.07
# 1594            6.2              0.60         0.08             2.0       0.09
# 1595            5.9              0.55         0.10             2.2       0.06
# 1596            6.3              0.51         0.13             2.3       0.08
# 1597            5.9              0.64         0.12             2.0       0.08
#
# ...

# %%
df_red["quality_label"]
# Out:
# 0          low
# 1          low
# 2          low
# 3       medium
# 4          low
#          ...
# 1594       low
# 1595    medium
# 1596    medium
# 1597       low
# 1598    medium
# Name: quality_label, Length: 1599, dtype: object

# %%
#1 The first plot you should do is a pie chart, showing the quantity of red wines compared to the quantity of white wines.
amount_redwine = df_red["quality"].value_counts().sum()
amount_whitewine = df_white["quality"].value_counts().sum()
y = np.array([amount_redwine, amount_whitewine])
mylabels = ["red wine", "white wine"]
mycolors = ["crimson", "#17becf"]
explode = [0.05,0]

#df_red.count() # 1599
#df_white.count() # 4898

#fig = plt.figure()
plt.figure(figsize=(8, 8), facecolor = "w")

plt.rcParams['text.color'] = 'darkblue'
plt.pie(y, labels = mylabels, colors = mycolors, explode = explode, autopct='%1.0f%%', startangle = 0 )
plt.title("Quantity of red and white wine")
plt.legend()
plt.show()

# %%
#2 create a plot to show the distribution of qualities. It should look similar to the one below

white_qualityl_count = df_white["quality_label"].value_counts()
plt.figure(figsize=(10, 6)) # Size of the plot

plt.bar(white_qualityl_count.index, white_qualityl_count, width=0.9, color="#17becf")

plt.title("Quality of white wine")
plt.xlabel("quality")
plt.ylabel("Count")
plt.xticks()
plt.show()

# %%
value_count_w = df_white["quality_label"].value_counts().sum
value_count_w
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of medium    3078
# low       1640
# high       180
# Name: quality_label, dtype: int64>

# %%
quality = df_white["quality_label"].value_counts()
quality
# Out:
# medium    3078
# low       1640
# high       180
# Name: quality_label, dtype: int64

# %%
white_quality_count = df_white["quality_label"].value_counts()
type(white_qualityl_count)
print(white_quality_count.values)
# Out:
# [3078 1640  180]

# %%
white_quality_count = df_white["quality_label"].value_counts()

plt.figure(figsize=(10, 6)) 

barplot = sns.countplot(x = df_white["quality_label"], order = ["low","medium","high"], color="#17becf")

plt.bar_label(barplot, labels = white_quality_count.values)
plt.title("Quality of white wine")
plt.xlabel("quality")
plt.ylabel("Count")
plt.xticks()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [34], line 7
#       3 plt.figure(figsize=(10, 6))
#       5 barplot = sns.countplot(x = df_white["quality_label"], order = ["low","medium","high"], color="#17becf")
# ----> 7 plt.bar_label(barplot, labels = white_quality_count.values)
#       8 plt.title("Quality of white wine")
#       9 plt.xlabel("quality")
#
# File c:\Users\satom\anaconda3\lib\site-packages\matplotlib\pyplot.py:2422, in bar_label(container, labels, fmt, label_type, padding, **kwargs)
#    2418 @_copy_docstring_and_deprecators(Axes.bar_label)
#    2419 def bar_label(
#    2420         container, labels=None, *, fmt='%g', label_type='edge',
#    2421         padding=0, **kwargs):
# -> 2422     return gca().bar_label(
#    2423         container, labels=labels, fmt=fmt, label_type=label_type,
#    2424         padding=padding, **kwargs)
#
# ...

# %%
white_quality_count = df_white["quality_label"].value_counts()

plt.figure(figsize=(10, 6)) 

barplot = sns.countplot(x = df_white["quality_label"], order = ["low","medium","high"], color="#17becf")

plt.bar_label(barplot, labels = white_quality_count.values)
plt.title("Quality of white wine")
plt.xlabel("quality")
plt.ylabel("Count")
plt.xticks()

#plt.bar_label(value_count)
def add_value ():
    for i in range(white_quality_count.values):
        plt.text(i)

add_value()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [107], line 7
#       3 plt.figure(figsize=(10, 6))
#       5 barplot = sns.countplot(x = df_white["quality_label"], order = ["low","medium","high"], color="#17becf")
# ----> 7 plt.bar_label(barplot, labels = white_quality_count.values)
#       8 plt.title("Quality of white wine")
#       9 plt.xlabel("quality")
#
# File c:\Users\satom\anaconda3\lib\site-packages\matplotlib\pyplot.py:2422, in bar_label(container, labels, fmt, label_type, padding, **kwargs)
#    2418 @_copy_docstring_and_deprecators(Axes.bar_label)
#    2419 def bar_label(
#    2420         container, labels=None, *, fmt='%g', label_type='edge',
#    2421         padding=0, **kwargs):
# -> 2422     return gca().bar_label(
#    2423         container, labels=labels, fmt=fmt, label_type=label_type,
#    2424         padding=padding, **kwargs)
#
# ...

# %%
plt.figure(figsize=(10, 6)) # Size of the plot

fig = sns.countplot(x = df_red["quality_label"], order = ["low","medium","high"], color="crimson")

plt.title("Quality of red wine")
plt.xlabel("quality")
plt.ylabel("Count")
plt.xticks()
fig.bar_label(fig.containers[0], label_type='edge')
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.subplot(121, title = "white wine quality")
sns.countplot(x = df_white["quality_label"],  order = ["low","medium","high"], color= "#17becf")
plt.xlabel("")

plt.subplot(122, title = "red wine quality")
sns.countplot(x = df_red["quality_label"],  order = ["low","medium","high"], color="crimson")
plt.xlabel("")
plt.ylim([0, 3300])
plt.subplots_adjust(wspace = 0.5)
plt.suptitle("quality of wines")
plt.show()

# %%
plt.figure(figsize=(10, 6))
mylabels = ["medium", "low", "high"]
mycolors = ["lightblue", "orange", "green"]

plt.subplot(121, title = "white wine quality")
plt.pie(white_qualityl_count, labels = mylabels, colors = mycolors, autopct='%1.0f%%', startangle =90, counterclock = False )

plt.subplot(122, title = "red wine quality")
plt.pie(red_qualityl_count, labels = mylabels, colors = mycolors, autopct='%1.0f%%', startangle =90, counterclock = False )

plt.suptitle("quantity of wines")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 plt.figure(figsize=(10, 6))
#       2 mylabels = ["medium", "low", "high"]
#       3 mycolors = ["lightblue", "orange", "green"]
#
# NameError: name 'plt' is not defined

# %%
white_count = df_white["quality_label"].value_counts()
red_count = df_red["quality_label"].value_counts()
display(white_count)
display(red_count)
type(red_count)
#fig, ax = plt.subplots()
#ax.boxplot(df_white["quality_label"])
#plt.show()
# Out:
# medium    3078
# low       1640
# high       180
# Name: quality_label, dtype: int64
# medium    837
# low       744
# high       18
# Name: quality_label, dtype: int64
# pandas.core.series.Series

# %%
# boxplot wine quality

plt.figure(figsize=(15, 10))

plt.subplot(121, title = "white wine quality")
sns.boxplot(y =df_white["quality"], color= "#17becf", width = 0.5)
plt.ylim(1,10)
plt.subplot(122, title = "red wine quality")
sns.boxplot(y =df_red["quality"], color = "crimson", width = 0.5)
plt.ylim(1,10)

plt.subplots_adjust(wspace = 0.5)
plt.suptitle("Box Plot -quantity of wines-")
plt.show()

# %%
# scatterplot white wine alcohol and density

plt.figure(figsize=(15, 10))

sns.scatterplot(x = "alcohol", y = "density", data=df_white)
plt.title("alcohol and density")
plt.show()

# %%
# scatterplot red wine alcohol and density

plt.figure(figsize=(15, 10))

sns.scatterplot(x = "alcohol", y = "density", data=df_red)
plt.title("alcohol and density")
plt.show()

# %%
# White wine correlation

plt.figure(figsize= (24,18))
mask = np.triu(np.ones_like(df_white.corr(), dtype=np.bool))
ax = sns.heatmap(df_white.corr(), vmin=-1, vmax = 1, mask = mask, annot=True, annot_kws={"size": 20},cmap="PiYG")
plt.xticks(rotation=45)
plt.title("correlation white wine")
plt.setp(ax.get_xticklabels(), fontsize=20)
plt.setp(ax.get_yticklabels(), fontsize=20)
plt.show()

# 目盛りラベルのフォントサイズを設定する
#plt.setp(ax.get_xticklabels(), fontsize=16)
# Out:
# C:\Users\satom\AppData\Local\Temp\ipykernel_29412\1530978221.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mask = np.triu(np.ones_like(df_white.corr(), dtype=np.bool))
# C:\Users\satom\AppData\Local\Temp\ipykernel_29412\1530978221.py:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(df_white.corr(), dtype=np.bool))
# ...

# %% [markdown]
# Free and Total sulfur dioxide are correlated highly but they don’t correlate with any other variables.
# Residual sugar has a strong correlation to density
# Alcohol and density has strong negative correlation

# %%
# red wine correlation

plt.figure(figsize= (24,18))
mask = np.triu(np.ones_like(df_red.corr(), dtype=np.bool))
ax = sns.heatmap(df_red.corr(), vmin=-1, vmax = 1, mask = mask, annot=True,annot_kws={"size": 20}, cmap = "BrBG")
plt.xticks(rotation=45)
plt.title("correlation red wine")
plt.setp(ax.get_xticklabels(), fontsize=20)
plt.setp(ax.get_yticklabels(), fontsize=20)

plt.show()
# Out:
# C:\Users\satom\AppData\Local\Temp\ipykernel_29412\440249103.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mask = np.triu(np.ones_like(df_red.corr(), dtype=np.bool))
# C:\Users\satom\AppData\Local\Temp\ipykernel_29412\440249103.py:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(df_red.corr(), dtype=np.bool))
# ...

# %% [markdown]
# Free and Total sulfur dioxide are correlated highly but they don’t correlate with any other variables.
# citric acid and fixed acidity are correlated highly
# ph and fixed acidity are highly correlated

# %%
# comparing density of white and red wine

fig, axs = plt.subplots(1, 2, sharey="row", tight_layout=True) # sharey = "row" makes the y-axis similar.
plt.figure(figsize = (15,10))
axs[0].set_title("density white wine")
axs[1].set_title("density red wine")

axs[0].hist(df_white['density'], color='darkgreen', bins=10,
         edgecolor='grey')
axs[1].hist(df_red['density'], color='lightgreen', bins=10,
         edgecolor='grey', linewidth=0.5)
# Out:
# (array([  8.,  27.,  90., 250., 485., 450., 185.,  74.,  19.,  11.]),
#  array([0.99007 , 0.991432, 0.992794, 0.994156, 0.995518, 0.99688 ,
#         0.998242, 0.999604, 1.000966, 1.002328, 1.00369 ]),
#  <BarContainer object of 10 artists>)

# %%
# histogram of red wine density

plt.figure(figsize=(10, 6))
plt.title("This is a histogram of red wine density")
plt.xlabel("density")

plt.hist(df_red["density"], color='crimson',
         edgecolor='grey', linewidth=0.5)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.title(" a histogram of red wine density")
plt.xlabel("density")

sns.histplot(df_red["density"], color='crimson',
         edgecolor='grey', linewidth=0.5)
plt.show()

# %% [markdown]
# we can say, that red wine density has normal distribution with peek between 0.996 and 0.998. density of red wine is between 0.990 and 1.004.

# %%
# histogram of white wine density

plt.figure(figsize=(10, 7))
plt.title("This is a histogram of red wine density")
plt.xlabel("density")

plt.hist(df_white["density"], bins = 10, ec = "grey", color="#17becf",
         edgecolor='grey', linewidth=0.5, density = False, fill=True)
plt.xlim(0.990, 1.005)
plt.show()

# %% [markdown]
# white wine density has right skewed distribution with peek between 0.992 and 0.998. density of red wine is between 0.990 and 1.002. so white wines density is smaller than the density of red wine. red wine has more range of density than red wine.

# %%
# boxplot quality label and alcohol white wine

plt.figure(figsize= (15,10)) 
plt.subplot(121, title = "white wine quality alcohol content ")
sns.boxplot(data = df_white, x = 'quality_label', y = "alcohol", order = ["low", "medium", "high"])

plt.ylim(7, 15)

plt.subplot(122, title = "Red wine quality alcohol content ")
sns.boxplot(data = df_red, x = 'quality_label', y = "alcohol")
plt.ylim(7, 15)
         
plt.show()

# %% [markdown]
# create same boxplot with other method

# %%
fig, axs = plt.subplots(1, 2, sharey="row", tight_layout=True) # sharey = "row" makes the y-axis similar.

axs[0].set_title("White wine quality and alcohol content")
axs[1].set_title("red wine quality and alcohol content")

axs[0].sns.boxplot(data = df_white, x = 'quality_label',y = "alcohol", order = ["low", "medium", "high"])
axs[1].sns.boxplot(data = df_red, x = 'quality_label', y = "alcohol", order = ["low", "medium", "high"])
         
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [145], line 6
#       3 axs[0].set_title("White wine quality and alcohol content")
#       4 axs[1].set_title("red wine quality and alcohol content")
# ----> 6 axs[0].sns.boxplot(data = df_white, x = 'quality_label',y = "alcohol", order = ["low", "medium", "high"])
#       7 axs[1].sns.boxplot(data = df_red, x = 'quality_label', y = "alcohol", order = ["low", "medium", "high"])
#       9 plt.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'sns'

# %% [markdown]
# In this boxplot we can see the low alcohol content tend to be low quality in red and white wine.
# But there are also outliers we can see. wine with too much alcohol with 15% seems to be low quality.

# %%
# boxplot quality label and pH red wine
plt.figure(figsize= (15,10)) 
plt.subplot(121, title = "white wine quality /pH ")
sns.boxplot(data = df_white, x = 'quality_label', y = "pH", order = ["low", "medium", "high"])


plt.subplot(122, title = "Red wine quality /pH ")
sns.boxplot(data = df_red, x = 'quality_label', y = "pH")
         
plt.show()

# %% [markdown]
# Trying to make boxplots with all columns with quality label

# %%
#with subplot
fig, ax = plt.subplot(3,3)
sns.boxplot(x='fixed acidity', y='volatile acidity', data=df_white, order = ["low", "medium", "high"], ax[0,0,0].title.set_text("fixed acidity and quality label"))
# Out:
#   Cell In [191], line 3
#     sns.boxplot(x='fixed acidity', y='volatile acidity', data=df_white, order = ["low", "medium", "high"], ax[0,0,0].title.set_text("fixed acidity and quality label"))
#                                                                                                            ^
# SyntaxError: positional argument follows keyword argument

# %%
cols = df_white.columns
cols
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'quality_label',
#        'alcohol_label'],
#       dtype='object')

# %%
# with for loop?
cols = df_white.columns
fig, axes = plt.subplots(4, 3, figsize=(25, 25))

for col, ax in cols:
    sns.boxplot(data = df_white, y = df_white[col], x = "quality_label")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [189], line 5
#       2 cols = df_white.columns
#       3 fig, axes = plt.subplots(4, 3, figsize=(25, 25))
# ----> 5 for col, ax in cols:
#       6     sns.boxplot(data = df_white, y = df_white[col], x = "quality_label")
#       8 plt.show()
#
# ValueError: too many values to unpack (expected 2)

# %%
plt.figure(figsize=(10,6))
plt.subplot(121)
sns.boxplot(x='quality_label', y='residual sugar', data=df_white, order = ["low", "medium", "high"])
# Out:
# <AxesSubplot:xlabel='quality_label', ylabel='residual sugar'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x='quality_label', y='residual sugar', data=df_red, order = ["low", "medium", "high"])
# Out:
# <AxesSubplot:xlabel='quality_label', ylabel='residual sugar'>

# %% [markdown]
# Creating charts with high correlation

# %%
# White wine: positive correlation 
# 1. density and residual sugar

plt.figure(figsize=(10,7))
sns.scatterplot(data = df_white, x = "residual sugar", y = "density")
plt.xlim(0, 30)
plt.show()

# %%
# 1. density and residual sugar

plt.figure(figsize=(10,7))
sns.regplot(x="residual sugar", y="density", data=df_white, ci = 70)
plt.xlim(0, 30)

plt.show()

# %%
#2 correlation between "total sulfur dioxide" and "free sulfur dioxide"

plt.figure(figsize=(15,10))
sns.regplot(x="total sulfur dioxide", y="free sulfur dioxide", data=df_white)
plt.show()

# %%
# negative correlation
plt.figure(figsize=(15,10))
sns.regplot(x="alcohol", y="density", data=df_white)
plt.show()

# %%
plt.hist(data = df_white, x = "quality", color = "blue", linewidth=0.5)
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.hist(x = df_white["fixed acidity"], color="#17becf" )
plt.title("fixed acidy")
plt.xlabel("fixed acidity   g(tartaricacid)/dm3")
plt.ylabel("count")
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='quality_label', y='fixed acidity', data=df_white)
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='quality_label', y='volatile acidity', order = ["low","medium", "high"], data=df_white)
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='quality_label', y='citric acid', order = ["low","medium", "high"], data=df_white)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df_white['density'], bins =20)
# Out:
# <AxesSubplot:xlabel='density', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(df_white['fixed acidity'], bins =20)
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
fig = sns.histplot(df_white['alcohol'], bins =10)
plt.title("alcohol content of white wine")
fig.bar_label(fig.containers[0], label_type='edge')
plt.show()

# %%
df_white['alcohol_label'] = df_white['alcohol'].apply(lambda value: 'low'
if value < 11.5 else 'high')
df_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df_white["alcohol_label"].value_counts()
# Out:
# low     3769
# high    1129
# Name: alcohol_label, dtype: int64

# %%
al_label = df_white["alcohol_label"].value_counts()
mylabels = ["low alcohol", "high alcohol"]
mycolors = ["lightblue", "blue"]
explode = [0.05,0]

#df_red.count() # 1599
#df_white.count() # 4898

#fig = plt.figure()
plt.figure(figsize=(8, 8), facecolor = "w")

plt.rcParams['text.color'] = 'darkblue'
plt.pie(al_label, labels = mylabels, colors = mycolors, explode = explode, autopct='%1.0f%%', startangle = 90, counterclock=False )
plt.title("alcohol content of white wine (low <11.5, high >11.5)")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.subplot(121)
sns.boxplot(x='quality_label', y='fixed acidity', data=df_white, order = ["low", "medium", "high"])
#
# Out:
# <AxesSubplot:xlabel='quality_label', ylabel='fixed acidity'>

# %%
plt.figure(figsize=(10,6))
plt.subplot(121)
sns.boxplot(x='quality_label', y='total sulfur dioxide', data=df_white, order = ["low", "medium", "high"])
# Out:
# <AxesSubplot:xlabel='quality_label', ylabel='total sulfur dioxide'>

# %%
plt.figure(figsize=(10,6))
plt.subplot(121)
sns.boxplot(x='quality_label', y='total sulfur dioxide', data=df_red, order = ["low", "medium", "high"])
# Out:
# <AxesSubplot:xlabel='quality_label', ylabel='total sulfur dioxide'>
